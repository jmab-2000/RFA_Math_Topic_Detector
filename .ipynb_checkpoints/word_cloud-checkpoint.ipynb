# %%
import matplotlib.pyplot as plt
import pandas as pd

mydata = pd.read_csv('dataset_after_transformation.csv', encoding='utf-8')

word_string=" ".join(mydata['question'].str.lower())
word_string
# Out:
# 'it is the sum of the terms of symbol(x) sequence find the sum of the first ten terms of the arithmetic sequence integer((d)) find the sum of the first integer((d)) terms of the arithmetic sequence integer((d)) integer((d)) integer((d)) … the sum of the first integer((d)) terms of an arithmetic sequence is integer((d)) what is the first term if the last term is integer((d)) and the common difference is integer((d)) the third term of an arithmetic sequence is −(d) and the seventh term is integer((d)) what is the sum of the first integer((d)) terms find the sum of the first integer((d)) terms of the arithmetic sequence if the first term is integer((d)) and the twentieth term is integer((d)) find the sum of the first eighteen terms of the arithmetic sequence whose nth term is the first term of an arithmetic sequence is integer((d)) the last term is integer((d)) and the sum is integer((d)) find the number of terms if the first symbol(x) terms of the arithmetic sequence integer((d)) integ
# ...

# %%
#Getting all the packages we need: 

import numpy as np # linear algebra
import pandas as pd # data processing

import seaborn as sns #statist graph package
import matplotlib.pyplot as plt #plot package

import wordcloud #will use for the word cloud plot
#from wordcloud import WordCloud, STOPWORDS # optional to filter out the stopwords

from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import nltk 
from nltk.corpus import stopwords

words = stopwords.words('english')

#Optional helpful plot stypes:
plt.style.use('bmh') #setting up 'bmh' as "Bayesian Methods for Hackers" style sheet
#plt.style.use('ggplot') #R ggplot stype

plt.figure(figsize=(15,15))
wc = WordCloud( stopwords = words, max_font_size= 300,  width=1600, height=800)
wc.generate(word_string)

plt.imshow(wc.recolor( colormap= 'viridis' , random_state=17), interpolation="bilinear")
plt.axis('off')
# Out:
# (-0.5, 1599.5, 799.5, -0.5)

# %%
mydata.label.unique()
# Out:
# array(['series_and_sequence', 'polynomials', 'polynomial_equation'],
#       dtype=object)

# %%
dindex = mydata.drop(columns=['Unnamed: 0'])
ss_table = dindex.loc[dindex['label'] =='series_and_sequence']
p_table = dindex.loc[dindex['label'] =='polynomials']
pe_table = dindex.loc[dindex['label'] =='polynomial_equation']

# %%
word_string=" ".join(ss_table['question'].str.lower())
plt.figure(figsize=(15,15))
wc = WordCloud( stopwords = words, max_font_size= 300,  width=1600, height=800)
wc.generate(word_string)

plt.imshow(wc.recolor( colormap= 'viridis' , random_state=17), interpolation="bilinear")
plt.axis('off')
# Out:
# (-0.5, 1599.5, 799.5, -0.5)

# %%
word_string=" ".join(p_table['question'].str.lower())
plt.figure(figsize=(15,15))
wc = WordCloud( stopwords = words, max_font_size= 300,  width=1600, height=800)
wc.generate(word_string)

plt.imshow(wc.recolor( colormap= 'viridis' , random_state=17), interpolation="bilinear")
plt.axis('off')
# Out:
# (-0.5, 1599.5, 799.5, -0.5)

# %%
word_string=" ".join(pe_table['question'].str.lower())
plt.figure(figsize=(15,15))
wc = WordCloud( stopwords = words, max_font_size= 300,  width=1600, height=800)
wc.generate(word_string)

plt.imshow(wc.recolor( colormap= 'viridis' , random_state=17), interpolation="bilinear")
plt.axis('off')
# Out:
# (-0.5, 1599.5, 799.5, -0.5)
